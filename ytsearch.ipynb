# %%
# !pip install boto3
# !pip install --upgrade google-api-python-client
# Out:
# Requirement already satisfied: boto3 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (1.34.47)
# Requirement already satisfied: botocore<1.35.0,>=1.34.47 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from boto3) (1.34.47)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from botocore<1.35.0,>=1.34.47->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from botocore<1.35.0,>=1.34.47->boto3) (1.26.18)
# Requirement already satisfied: six>=1.5 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.47->boto3) (1.16.0)
# Requirement already satisfied: google-api-python-client in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (2.118.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-python-client) (2.28.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-python-client) (2.17.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lily/anaconda3/envs/tts-yt/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)

# %%
import boto3
import hashlib
import json
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from YTsearch_options_cycler import SearchOptionsCycler
import yt_dlp
from datetime import datetime
from dotenv import load_dotenv


def current_timestamp():
    """Returns the current timestamp formatted for readability."""
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def get_env_variables():
    """Fetch all necessary configurations from environment variables."""
    return {
        'DEVELOPER_KEY': os.getenv('DEVELOPER_KEY'),
        'AWS_ACCESS_KEY_ID': os.getenv('AWS_ACCESS_KEY_ID'),
        'AWS_SECRET_ACCESS_KEY': os.getenv('AWS_SECRET_ACCESS_KEY'),
        'SEARCH_CACHE_TABLE': os.getenv('SEARCH_CACHE_TABLE'),
        'RESULTS_TABLE_NAME': os.getenv('RESULTS_TABLE_NAME'),
        'SEARCH_QUERY': os.getenv('SEARCH_QUERY'),
        'MAX_RESULTS': int(os.getenv('MAX_RESULTS', 50)),
        'ORDER': os.getenv('ORDER', 'viewCount'),
        'VIDEO_DURATION': os.getenv('VIDEO_DURATION', 'medium'),
        'PUBLISHED_AFTER': os.getenv('PUBLISHED_AFTER', '2010-01-01T00:00:00Z'),
        'PUBLISHED_BEFORE': os.getenv('PUBLISHED_BEFORE', '2024-12-31T23:59:59Z'),
        'RELEVANCE_LANGUAGE': os.getenv('RELEVANCE_LANGUAGE', 'en'),
        # 'VIDEO_CATEGORY_ID': os.getenv('VIDEO_CATEGORY_ID', '10'),
        'AWS_REGION': os.getenv('AWS_REGION')  # Add AWS region to the environment variables
    }

def open_aws_dynamodb_session(options):
    """
    Configures a boto3 session using AWS credentials read from environment variable.
    Returns a boto3 DynamoDB resource configured with these credentials.
    """
    try:

        # Configure the boto3 session with the read credentials
        session = boto3.Session(
            aws_access_key_id=options['AWS_ACCESS_KEY_ID'],
            aws_secret_access_key=options['AWS_SECRET_ACCESS_KEY'],
            region_name=options['AWS_REGION']  # Specify your AWS region
        )
        dynamodb_resource = session.resource('dynamodb')
        print(f"Successfully open_aws_dynamodb_session with environment variables. at {current_timestamp()}\n")
        # Return the configured DynamoDB resource
        return dynamodb_resource

    except Exception as e:
        print(f"Error open_aws_dynamodb_session from environment variables: {e} at {current_timestamp()}\n")
        return None


def first_time_check_cache(options, dynamodb):
    """Check if search options are in the cache on AWS DynamoDB."""
    print(f"Checking cache at {current_timestamp()}\n")
    non_search_terms = ['DEVELOPER_KEY', 'AWS_ACCESS_KEY_ID', 'AWS_SECRET_ACCESS_KEY', 'SEARCH_CACHE_TABLE', 'RESULTS_TABLE_NAME', 'AWS_REGION', 'MAX_RESULTS']
    search_query_options = {k: v for k, v in options.items() if k not in non_search_terms}
    key = json.dumps(search_query_options, sort_keys=True)
    try:
        cache_table = dynamodb.Table(options['SEARCH_CACHE_TABLE'])
        response = cache_table.get_item(
        Key={
                'CacheKey': key
                # 'Timestamp': sort_key_value  # You'll need to provide the appropriate sort key value here
            }
        )
        if 'Item' in response:
            print("Cache hit.")
            return response
    except Exception as e:
        print(f"Error accessing DynamoDB due to 'check_cache' malfunctioniong: {e} at {current_timestamp()}\n")
    print("Cache miss.\n")
    return {'Item': {'Timestamp': '2024-02-28 15:03:32', 'CacheKey': '{"ORDER": "relevance", "PUBLISHED_AFTER": "2010-01-01T00:00:00Z", "PUBLISHED_BEFORE": "2024-12-31T23:59:59Z", "RELEVANCE_LANGUAGE": "en", "SEARCH_QUERY": "affirmation", "VIDEO_DURATION": "medium"}'}, 'ResponseMetadata': {'RequestId': 'QJN027G2KSUGOH95GUQH2G70UNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 06:23:28 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '290', 'connection': 'keep-alive', 'x-amzn-requestid': 'QJN027G2KSUGOH95GUQH2G70UNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '3681715306'}, 'RetryAttempts': 0}}

def check_cache(dynamodb, full_youtube_cycled_options_dict):
    """Check if search options are in the cache on AWS DynamoDB."""
    print(f"Checking cache at {current_timestamp()}\n")
    key = json.dumps(full_youtube_cycled_options_dict, sort_keys=True)
    # sort_key_value = current_timestamp()

    try:
        cache_table = dynamodb.Table(options['SEARCH_CACHE_TABLE'])
        response = cache_table.get_item(
        Key={
                'CacheKey': key #,
                # 'Timestamp': sort_key_value  # You'll need to provide the appropriate sort key value here
            }
        )
        if 'Item' in response:
            print("Cache hit.")
            return response
    except Exception as e:
        print(f"Error accessing DynamoDB due to 'check_cache' malfunctioniong: {e} at {current_timestamp()}\n")
    print("Cache miss.\n")
    return None

def update_cache(dynamodb, full_youtube_cycled_options_dict):
    """Update the cache with new search results, including the search time."""
    print(f"Updating cache at {current_timestamp()}\n")
    
    timestamp = current_timestamp()  # Capture the search timestamp
    key = json.dumps(full_youtube_cycled_options_dict, sort_keys=True)
    try:
        search_cache_table = options['SEARCH_CACHE_TABLE']
        cache_table = dynamodb.Table(search_cache_table)
        cache_table.put_item(Item={
            'CacheKey': key,
            'Timestamp': timestamp  # Store the search time
        })
        return True
    except Exception as e:
        print(f"Error updating DynamoDB due to 'update_cache' malfunctioniong: {e} at {current_timestamp()}\n")
        return False

def merge_dicts_return_larger(dict1, dict2):
    # Determine which dictionary is larger
    larger_dict = dict1 if len(dict1) > len(dict2) else dict2
    smaller_dict = dict2 if larger_dict is dict1 else dict1

    # Update the values of the larger dictionary with values from the smaller dictionary
    # Gets any unique keys from the smaller dictionary.
    for key in smaller_dict.keys():
        if key in larger_dict:
            # Update the larger dictionary with values from the smaller one
            larger_dict[key] = smaller_dict[key]

    # Output the larger dictionary with updated values
    return larger_dict

def youtube_search_all_videos(options, dynamodb):
    """Perform a search on YouTube Data API and return all videos based on the options, with caching and paging."""
    print(f"Performing YouTube search at {current_timestamp()}\n")

    developer_key = options['DEVELOPER_KEY']
    youtube = build('youtube', 'v3', developerKey=developer_key)
    
    all_videos = []
    page_token = None
    max_iterations = 50  # Adjust based on how many pages you want to retrieve

    try:
        for _ in range(max_iterations):
            search_response = youtube.search().list(
                q=options['SEARCH_QUERY'],
                part='id,snippet',
                maxResults=options['MAX_RESULTS'],
                order=options['ORDER'],
                type='video',
                videoDuration=options['VIDEO_DURATION'],
                publishedAfter=options['PUBLISHED_AFTER'],
                publishedBefore=options['PUBLISHED_BEFORE'],
                relevanceLanguage=options['RELEVANCE_LANGUAGE'],
                # videoCategoryId=options['VIDEO_CATEGORY_ID'], # When there is a category ID assigned, if number 10, then results are mostly music.
                pageToken=page_token
            ).execute()

            # Create a temporary map of video ID to search result item
            video_id_to_search_item = {}
            for item in search_response.get('items', []):
                video_id = item['id']['videoId']
                video_id_to_search_item[video_id] = item
        
            video_ids = list(video_id_to_search_item.keys())
        
            if video_ids:
                details_response = youtube.videos().list(
                    id=','.join(video_ids),
                    part='contentDetails,statistics,status,topicDetails,liveStreamingDetails,localizations'
                ).execute()
        
                # Update search result items with additional details
                for detail_item in details_response.get('items', []):
                    video_id = detail_item['id']
                    if video_id in video_id_to_search_item:
                        # Combine the detail item with the search result item
                        search_item = video_id_to_search_item[video_id]
                        search_item['details'] = detail_item  # Add a new key for additional details
                        
                        # Append the updated search item to all_videos
                        all_videos.append(search_item)
        
            page_token = search_response.get('nextPageToken')
            if not page_token:
                break

    except HttpError as e:
        print(f"An HTTP error occurred: {e.resp.status} {e.content} at {current_timestamp()}\n")

    print(f"Function 'youtube_search_all_videos' was run at {current_timestamp()}\n")
    return all_videos


def send_to_dynamodb(options, dynamodb, flattened_single_video_dict):   
    """Send Youtube Data API results on the video and subtitle transcripts to Dynamodb."""
    try:
        results_table_name = options['RESULTS_TABLE_NAME']
        results_table = dynamodb.Table(results_table_name)
        response = results_table.put_item(Item=flattened_single_video_dict)
        print(f"Successfully inserted api results into DynamoDB  at {current_timestamp()}\n", response)
    except Exception as e:
        print(f"Error inserting into DynamoDB: {e}")
    
def flatten_dict(d):
    """
    Flatten a nested dictionary, concatenating keys with a specified separator.

    :param d: The dictionary to flatten
    :param parent_key: The base key string to use for constructing new key names
    :param sep: The separator to use between concatenated keys
    :return: A flattened dictionary
    """
    parent_key=''
    sep='-'
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v).items())
        else:
            items.append((new_key, v))
    return dict(items)



def main():

    # Load the .env file
    load_dotenv()
    
    # text file of youtube search terms to cycle through
    file_path = 'search_queries.txt'
    
    # Get environment variables
    options = get_env_variables()
    
    # Only proceed if options were successfully retrieved
    if options:
        dynamodb = open_aws_dynamodb_session(options)
        
        # Only proceed if DynamoDB was successfully configured
        if dynamodb:
    
            # use default values to do a search, using environment variable defaults
            full_cache_table_value = first_time_check_cache(options, dynamodb)
            long_dict = json.loads(full_cache_table_value['Item']['CacheKey'])
            
            # initialize cache cycler
            cycler = SearchOptionsCycler(file_path)
            
            # start with cycling through order as the search option values to rotate
            cycler.set_cycling_attribute('ORDER')
            # cycle for the first time
            youtube_cycled_options_dict = cycler.get_next_options()
    
            # combine the full search terms from environment variables updated with just the new values that got cycled
            full_search_term_cycled_dict = merge_dicts_return_larger(long_dict, youtube_cycled_options_dict)
    
            # while cache hit, cycle through youtube search options
            while check_cache(dynamodb, full_search_term_cycled_dict):
                # generate new cycled options, which is a subset of what gets sent to the youtube api
                youtube_cycled_options_dict = cycler.get_next_options()
                # combine the full search terms from environment variables updated with just the new values that got cycled
                full_search_term_cycled_dict = merge_dicts_return_larger(long_dict, youtube_cycled_options_dict)
                
            # if not a cache hit, store new search terms
            update_cache(dynamodb, full_search_term_cycled_dict)
            video_list = youtube_search_all_videos(options, dynamodb)
            # print(all_videos)
            # # Only proceed if videos were successfully retrieved
            for single_video_dict in video_list:
                flattened_single_video_dict = flatten_dict(single_video_dict)
                # print(video['id']['videoId'])
                print(json.dumps(flattened_single_video_dict, indent=4))
                send_to_dynamodb(options, dynamodb, flattened_single_video_dict)
        else:
            print(f"Failed to configure boto3 from environment variables at {current_timestamp()}. Exiting...\n")
    else:
        print(f"Failed to retrieve environment variables at {current_timestamp()} Exiting...\n")

if __name__ == "__main__":
    main()
# Out:
# Successfully open_aws_dynamodb_session with environment variables. at 2024-02-29 00:20:01
#
# Checking cache at 2024-02-29 00:20:01
#
# Cache hit.
# Checking cache at 2024-02-29 00:20:01
#
# Cache hit.
# Checking cache at 2024-02-29 00:20:01
#
# Cache hit.
# Checking cache at 2024-02-29 00:20:01
#
# Cache miss.
#
# Updating cache at 2024-02-29 00:20:02
#
# Performing YouTube search at 2024-02-29 00:20:02
#
# Function 'youtube_search_all_videos' was run at 2024-02-29 00:20:32
#
# {
#     "kind": "youtube#video",
#     "etag": "7x_E1heuhDUph9WruDaTyJIEUYo",
#     "videoId": "RFzZ-xpyfoo",
#     "publishedAt": "2011-03-17T23:21:39Z",
#     "channelId": "UCocAlqGOU7BqzKc87qx6WUg",
#     "title": "Savage Garden - Affirmation",
#     "description": "Savage Garden's official music video for 'Affirmation'. Click to listen to Savage Garden on Spotify: http://smarturl.it/SGSpot?",
#     "url": "https://i.ytimg.com/vi/RFzZ-xpyfoo/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "SavageGardenVEVO",
#     "liveBroadcastContent": "none",
#     "publishTime": "2011-03-17T23:21:39Z",
#     "id": "RFzZ-xpyfoo",
#     "duration": "PT4M11S",
#     "dimension": "2d",
#     "definition": "sd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "17077788",
#     "likeCount": "58289",
#     "favoriteCount": "0",
#     "commentCount": "3013",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Music",
#         "https://en.wikipedia.org/wiki/Pop_music"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'CK2GD3F3UBES4RUSIQGR4IHH4JVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'CK2GD3F3UBES4RUSIQGR4IHH4JVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "w1IEyLHOt8rk4pvV7j9Kt5SObM8",
#     "videoId": "yo1pJ_D-H3M",
#     "publishedAt": "2022-02-05T14:00:24Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Positive Affirmations for Self Love, Self Esteem, Confidence \ud83d\udcab",
#     "description": "Powerful positive affirmations for self love, self esteem, confidence & self worth. Listen to these self love affirmations for 21 ...",
#     "url": "https://i.ytimg.com/vi/yo1pJ_D-H3M/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-02-05T14:00:24Z",
#     "id": "yo1pJ_D-H3M",
#     "duration": "PT14M31S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "6876163",
#     "likeCount": "132184",
#     "favoriteCount": "0",
#     "commentCount": "2872",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'DALL95G3LM3JVUFVMQBSVUMHEBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'DALL95G3LM3JVUFVMQBSVUMHEBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "kE1sWrbmVAtL5jjJeqYNY7VnOes",
#     "videoId": "Ud_eeFkzH4w",
#     "publishedAt": "2018-05-09T22:43:16Z",
#     "channelId": "UCTFG_PeBqjz1zG1apCH8tVw",
#     "title": "33 POSITIVE AFFIRMATIONS FOR KIDS SELF ESTEEM - (WATCH AT LEAST ONCE A DAY) | #positiveaffirmations",
#     "description": "CHECK OUT THIS VIDEO NEXT: https://bit.ly/3LBnkSB Subscribe for more! MORE SANDZ ACADEMY AFFIRMATION VIDEOS: 26 ...",
#     "url": "https://i.ytimg.com/vi/Ud_eeFkzH4w/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "SandZ Academy",
#     "liveBroadcastContent": "none",
#     "publishTime": "2018-05-09T22:43:16Z",
#     "id": "Ud_eeFkzH4w",
#     "duration": "PT4M10S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": true,
#     "viewCount": "5856993",
#     "likeCount": "39572",
#     "favoriteCount": "0",
#     "commentCount": "0"
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'RT1UGSODU8VINNGME681S16V7RVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'RT1UGSODU8VINNGME681S16V7RVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "8blPE2WQSXrxRtcFYN1upnklAzQ",
#     "videoId": "uT6ASPy2Dbs",
#     "publishedAt": "2022-06-23T12:00:43Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Powerful Positive Morning Affirmations \u2600\ufe0f start your day w/ bright beautiful energy",
#     "description": "Powerful positive affirmations for self love, gratitude, confidence & joy. Use these morning affirmations to raise your vibration ...",
#     "url": "https://i.ytimg.com/vi/uT6ASPy2Dbs/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-06-23T12:00:43Z",
#     "id": "uT6ASPy2Dbs",
#     "duration": "PT11M7S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "2299522",
#     "likeCount": "40068",
#     "favoriteCount": "0",
#     "commentCount": "695",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'RQ7T0RIUCBDF7BGA08DOE3EMGNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'RQ7T0RIUCBDF7BGA08DOE3EMGNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "pIdTa3I6HOaXr076x8UIfPEd70o",
#     "videoId": "j71q6zlbO3I",
#     "publishedAt": "2019-09-25T22:45:52Z",
#     "channelId": "UCqLQntNxiX-eCU2Xy9CjzMw",
#     "title": "I AM Morning Affirmations for Women | Powerful Guided Meditation 432 Hz Healing Frequency",
#     "description": "Our thoughts create our reality. Program your mind to think positive thoughts daily with these positive I AM morning affirmations.",
#     "url": "https://i.ytimg.com/vi/j71q6zlbO3I/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Alanna Foxx",
#     "liveBroadcastContent": "none",
#     "publishTime": "2019-09-25T22:45:52Z",
#     "id": "j71q6zlbO3I",
#     "duration": "PT14M45S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "12817861",
#     "likeCount": "238311",
#     "favoriteCount": "0",
#     "commentCount": "5205",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': '5L7K962OGST0GKTEOD51D80D8FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '5L7K962OGST0GKTEOD51D80D8FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "rKlaaDPix4PKFMtoH0wpTyGCPlc",
#     "videoId": "efZFARmGyMs",
#     "publishedAt": "2023-08-04T13:00:34Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Positive Affirmations to Change Your Life \ud83e\udd8b\u2728 33 Powerful Daily Affirmations",
#     "description": "Powerful positive affirmations to change your life for the better. Listen to these affirmations daily for 21 days to reprogram your ...",
#     "url": "https://i.ytimg.com/vi/efZFARmGyMs/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2023-08-04T13:00:34Z",
#     "id": "efZFARmGyMs",
#     "duration": "PT16M35S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "1377160",
#     "likeCount": "26149",
#     "favoriteCount": "0",
#     "commentCount": "580",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'ACHS8FDNKMIGBT59F1H7GVDEC3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'ACHS8FDNKMIGBT59F1H7GVDEC3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "8uCpDoi0uo-fjdHsJPWv3l-3BmQ",
#     "videoId": "hGWHI2tBR8A",
#     "publishedAt": "2024-01-02T07:00:25Z",
#     "channelId": "UCi0QjroJL314duVJlpxYynQ",
#     "title": "I AM Morning Affirmations for Success | LISTEN EVERY DAY",
#     "description": "Listen to these powerful I AM affirmations every morning for success, happiness, and abundance.\n\n#affirmations #success\n\nWake Me Up is the # 1 guided morning routine podcast. Our guided morning wake ups offer mindfulness, meditation, yoga, and motivation specifically designed to help you get out of bed and start your day with a positive mindset. Stop pressing the snooze button all morning long, and turn on an episode of Wake Me Up instead. You will be happier and more successful at everything in life because of it! \n\nTry out our different kinds of episodes to see what you like. And add it into your morning routine every day. Each day, you will be happier than the day before :)\n\nLeave a comment if you liked this episode! And don't forget to subscribe, so you never miss a new episode.\n\nYou can listen to Wake Me Up in audio-only format on your favorite podcast player! Visit www.wakemeuppodcast.com to learn more.\n\nWant more Wake Me Up? Join Wake Me Up Premium to get instant access to the entire WMU catalog of 400 episodes, including exclusive bonus episodes only available to premium supporters. Learn more and sign up here: https://wakemeup.supercast.com/\n\nFollow Wake Me Up on Instagram @wakemeuppodcast or TikTok @wakemeuppodcast.\n\nWarning about stretches, breathing, and other techniques: Only partake in the physical movements and practices suggested in Wake Me Up episodes if you are physically able and in safe surroundings. All movements are done at the individual's own risk. Be safe, and always consult a doctor if you have any questions or concerns.\n\n\n00:00 Introduction\n01:10 Affirmations begin\n11:15 Conclusion",
#     "url": "https://i.ytimg.com/vi/hGWHI2tBR8A/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Wake Me Up",
#     "liveBroadcastContent": "none",
#     "publishTime": "2024-01-02T07:00:25Z",
#     "id": "hGWHI2tBR8A",
#     "duration": "PT12M18S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "206695",
#     "likeCount": "9193",
#     "favoriteCount": "0",
#     "commentCount": "574",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'B6DQ0942NK1D79MKH5P1O4COFBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'B6DQ0942NK1D79MKH5P1O4COFBVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "V6zBWEKDKa2Uqo2xiQPOXbnlzhs",
#     "videoId": "ZssjZnsN4Gg",
#     "publishedAt": "2018-06-05T02:00:02Z",
#     "channelId": "UCqPYhcdFgrlUXiGmPRAej1w",
#     "title": "POWERFUL POSITIVE Morning Affirmations for POSITIVE DAY, WAKE UP: 21 Day \"I AM\"  Affirmations",
#     "description": "Embark on a transformative 21-day journey to manifest wealth, abundance, and prosperity in your life with our \"I AM\" Sleep Meditation Program. Drift into a peaceful slumber while affirming your financial goals, allowing your subconscious mind to work its magic as you sleep. This affirmation meditation is designed to help you reprogram your mindset for success, abundance, and financial freedom. Wake up each day with renewed determination and a deep sense of prosperity. Start your 21-day transformation tonight!\n\nReceive your FREE resources here: https://jasonstephenson.net/lp/free-resources/\n\n#positiveaffirmations\n#affirmations \n#jasonstephenson \n#sleepmeditationmusic \n#affirmations \n\nYou might like to also try this: Affirmations to release toxic emotions: https://www.youtube.com/watch?v=IH9GuJWGM0Q \n\n\u00a9 JASON STEPHENSON & RELAX ME ONLINE AUSTRALIA PTY LTD Copyright 2018 All rights reserved.\n\nThis work is not intended to substitute for professional medical or counselling advice. If you suffer from a physical or mental illness, please always seek professional help.  \n\nDO NOT DRIVE OR OPERATE MACHINERY WHILST LISTENING TO SLEEP MEDITATION MUSIC, BINAURAL BEATS OR GUIDED SLEEP RELAXATIONS.",
#     "url": "https://i.ytimg.com/vi/ZssjZnsN4Gg/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Jason Stephenson - Sleep Meditation Music",
#     "liveBroadcastContent": "none",
#     "publishTime": "2018-06-05T02:00:02Z",
#     "id": "ZssjZnsN4Gg",
#     "duration": "PT11M32S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": false,
#     "madeForKids": false,
#     "viewCount": "15547112",
#     "likeCount": "175610",
#     "favoriteCount": "0",
#     "commentCount": "5426",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)",
#         "https://en.wikipedia.org/wiki/Religion"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'IAO07UO9POB0LTPKB99QOKR397VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'IAO07UO9POB0LTPKB99QOKR397VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "8uZzvbnToLBNyaejkhKrfKqXC7A",
#     "videoId": "b7ImX9KfqYs",
#     "publishedAt": "2024-02-28T00:00:22Z",
#     "channelId": "UCZzSQjgsdrfw3UU0g-jhIzQ",
#     "title": "Night Affirmations | LISTEN TO THIS EVERY NIGHT Before You Sleep | Peaceful Restful Night",
#     "description": "forsleep #sleepmeditation #stressrelief #sleepaffirmations Possibly ,The Most Relaxing, Calming & Peaceful Affirmations with ...",
#     "url": "https://i.ytimg.com/vi/b7ImX9KfqYs/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Angel Empowerment",
#     "liveBroadcastContent": "none",
#     "publishTime": "2024-02-28T00:00:22Z",
#     "id": "b7ImX9KfqYs",
#     "duration": "PT4M36S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": false,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "111",
#     "likeCount": "2",
#     "favoriteCount": "0",
#     "commentCount": "0",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:32
#  {'ResponseMetadata': {'RequestId': 'VI2MT3UEOROO5V1UFB0NC4BP5JVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:32 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'VI2MT3UEOROO5V1UFB0NC4BP5JVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "TjTc37r9LJG6tpxtyFHtvbcnDLA",
#     "videoId": "2bbHZusVgw0",
#     "publishedAt": "2018-06-02T13:21:37Z",
#     "channelId": "UC0dJDW1i1vgwGXJ19wjIHPg",
#     "title": "Morning I AM Affirmations to Attract Wealth & Abundance! 21 Day Challenge!",
#     "description": "Morning I AM affirmations to attract wealth, abundance and prosperity. Start your day with these powerful, positive morning affirmations, inspired by Abraham Hicks, Louise Hay, Deepak Chopra, and Wayne Dyer. Take this 21 day meditation challenge and listen to these powerful I AM affirmations every morning for 21 days in a row. You just might be amazed by what shows up in your life.\n\nDOWNLOAD 6 of my favorite affirmation and guided meditation recordings FREE. My gift to you. Get them here: https://BobBakerInspiration.com/free\n\n0:00 Intro\n1:43 Affirmations begin\n13:55 Final affirmation\n\nSUBSCRIBE to the channel so you don\u2019t miss all the new videos I publish every week\nhttps://www.youtube.com/channel/UC0dJDW1i1vgwGXJ19wjIHPg?sub_confirmation=1\n\nSAMPLE the \u201c21-Day Abundance and Money Attraction Brain Boost\u201d for free at\nhttps://soulmassage.bandcamp.com/album/21-day-abundance-and-money-attraction-brain-boost\n\nFOLLOW Bob Baker\u2019s Inspiration Project on Spotify\nhttps://open.spotify.com/artist/2h5dkU6stcyzAXjMcgb1fe\n\nSTREAM & PURCHASE tracks on Apple Music\nhttps://music.apple.com/us/artist/bob-bakers-inspiration-project/1388646816\n\nThanks to https://BetterHelp.com/BobBaker for sponsoring this episode. Yes, you can take important steps to improve your mindset, but if you\u2019re really having a tough time, don\u2019t try to power through it alone. Get the help you need from a licensed therapist. If you use the BetterHelp service, I will receive a commission. That won\u2019t affect your rate at all, but it will help support my channel so I can create more videos like this one.\n\n=====\n\nAlso enjoy these YouTube playlists ...\n\nMorning Affirmations for Wealth, Abundance and Confidence\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHomHEiGaCIwgQGc6MnKfvx0\n\nGuided Meditations for Wealth, Abundance and Creativity\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHpxMsebKoEm7qHO14T4KJVE\n\nAffirmations for Creativity, Success and Abundance\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHrIgeCbuuWQVZD0SL91bHjb\n\n21 Day Meditation Challenge Videos\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHq8UnWVH66CYWQDW5mDkUG8\n\nGuided Meditations for Relaxation and Stress Relief\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHoGG9IFP-bbhIP_LyT3-5eX\n\nBedtime Sleep Affirmations for Prosperity, Success & Abundance\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHq1Mn796oKmiu63oo8mRG9q\n\nAffirmations for Health, Healing & Weight Loss\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHpwSp6bGTqbo2qVc3uSfOh7\n\nGratitude Affirmations for Morning and Bedtime\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHqE1jsDOHSM0JfWDZJcmEOd\n\nLIKE my Bob Baker Inspiration page on Facebook\nhttps://www.facebook.com/BobBakerInspiration/\n\n=====\n\nWritten and read by Bob Baker.\n\nBackground music used in this video:\n\u201cThat Hopeful Future Is All I've Ever Known\u201d from the album \u201cMusic from Neptune Flux\u201d by Chris Zabriskie http://chriszabriskie.com/neptuneflux/\nLicensed under a Creative Commons Attribution license https://creativecommons.org/licenses/by/4.0/\n\n=====\n\n#Affirmations #MorningAffirmations #IAMAffirmations #IAM #MorningMeditation #StartTheDay #StartYourDay #wealth #abundance #prosperity\n\nMorning Affirmations To Start Your Day On The Right Foot (Daily Affirmations)\npositive affirmations to start your day\n21 day meditation challenge\nmorning i am affirmations\nbob baker affirmations\nHonest guys\nmorning Abraham Hicks\npositive morning motivation\nmorning Wayne dyer\npositive morning meditation\nmorning affirmations Louise Hay\nmorning Deepak Chopra\n42 morning affirmations\nmorning Jason Stephenson\n\n=====\n\nAlso, I've published many books over the years, including \u2026\n\nPersonal and Spiritual Growth for Fun People: The Secret Guide to Joy and Prosperity\nEbook https://amzn.to/2vkVFzx\nAudiobook https://amzn.to/2vaGad2\n\nThe Empowered Artist: A  ...
#     "url": "https://i.ytimg.com/vi/2bbHZusVgw0/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Bob Baker Affirmations",
#     "liveBroadcastContent": "none",
#     "publishTime": "2018-06-02T13:21:37Z",
#     "id": "2bbHZusVgw0",
#     "duration": "PT14M12S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "7351580",
#     "likeCount": "90862",
#     "favoriteCount": "0",
#     "commentCount": "2722",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'SJOG75HUDUP9RF53H7BLBSGB3RVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'SJOG75HUDUP9RF53H7BLBSGB3RVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "_ApZUmaAoKGrCMbRG0qp9RNNYco",
#     "videoId": "1sMENEvEaDw",
#     "publishedAt": "2023-05-29T14:15:58Z",
#     "channelId": "UC64KwGynvj3hA7T0C9gC5cA",
#     "title": "Listen to this everyday for beauty and confidence (REUPLOAD)",
#     "description": "Relaxing Chill Music | ARNOR by Alex-Productions | https://onsound.eu/ Music promoted by https://www.chosic.com/free-music/all/ ...",
#     "url": "https://i.ytimg.com/vi/1sMENEvEaDw/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Thewizardliz",
#     "liveBroadcastContent": "none",
#     "publishTime": "2023-05-29T14:15:58Z",
#     "id": "1sMENEvEaDw",
#     "duration": "PT8M9S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "3605232",
#     "likeCount": "158598",
#     "favoriteCount": "0",
#     "commentCount": "2319"
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': '2PPOVBGV3AE6S5C0PD2HQROGMNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '2PPOVBGV3AE6S5C0PD2HQROGMNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "GgOOuueVuvJEQsPV5sRzui74cE4",
#     "videoId": "TN-xKFd2wIE",
#     "publishedAt": "2024-02-21T07:00:21Z",
#     "channelId": "UCi0QjroJL314duVJlpxYynQ",
#     "title": "Positive Thinking Morning Affirmations Meditation 10 Minutes | Think Positive",
#     "description": "This morning, enjoy a calming 10 minute meditation filled with positive thinking affirmations. Nurture a positive mindset as you begin your day. Repeat these for 21 days, and see how it changes not only your day, but your entire life.\n\n#morningaffirmations #morningmeditation #affirmations #affirmationsmeditation \n\nWake Me Up is the # 1 guided morning routine podcast. Our guided morning wake ups offer mindfulness, meditation, yoga, and motivation specifically designed to help you get out of bed and start your day with a positive mindset. Stop pressing the snooze button all morning long, and turn on an episode of Wake Me Up instead. You will be happier and more successful at everything in life because of it! \n\nTry out our different kinds of episodes to see what you like. And add it into your morning routine every day. Each day, you will be happier than the day before :)\n\nLeave a comment if you liked this episode! And don't forget to subscribe, so you never miss a new episode.\n\nYou can listen to Wake Me Up in audio-only format on your favorite podcast player! Visit www.wakemeuppodcast.com to learn more.\n\nWant more Wake Me Up? Join Wake Me Up Premium to get instant access to the entire WMU catalog of 400 episodes, including exclusive bonus episodes only available to premium supporters. Learn more and sign up here: https://wakemeup.supercast.com/\n\nFollow our network on Instagram and TikTok @_heychamp \n\nWarning about stretches, breathing, and other techniques: Only partake in the physical movements and practices suggested in Wake Me Up episodes if you are physically able and in safe surroundings. All movements are done at the individual's own risk. Be safe, and always consult a doctor if you have any questions or concerns.\n\n00:00 Introduction\n01:00 Meditation begins\n02:45 Affirmations begin\n09:13 Conclusion",
#     "url": "https://i.ytimg.com/vi/TN-xKFd2wIE/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Wake Me Up",
#     "liveBroadcastContent": "none",
#     "publishTime": "2024-02-21T07:00:21Z",
#     "id": "TN-xKFd2wIE",
#     "duration": "PT10M",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "22918",
#     "likeCount": "1538",
#     "favoriteCount": "0",
#     "commentCount": "181",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': '3LVA5BN5USF11A877RNR3LUAEVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '3LVA5BN5USF11A877RNR3LUAEVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "GgOOuueVuvJEQsPV5sRzui74cE4",
#     "videoId": "TN-xKFd2wIE",
#     "publishedAt": "2024-02-21T07:00:21Z",
#     "channelId": "UCi0QjroJL314duVJlpxYynQ",
#     "title": "Positive Thinking Morning Affirmations Meditation 10 Minutes | Think Positive",
#     "description": "This morning, enjoy a calming 10 minute meditation filled with positive thinking affirmations. Nurture a positive mindset as you begin your day. Repeat these for 21 days, and see how it changes not only your day, but your entire life.\n\n#morningaffirmations #morningmeditation #affirmations #affirmationsmeditation \n\nWake Me Up is the # 1 guided morning routine podcast. Our guided morning wake ups offer mindfulness, meditation, yoga, and motivation specifically designed to help you get out of bed and start your day with a positive mindset. Stop pressing the snooze button all morning long, and turn on an episode of Wake Me Up instead. You will be happier and more successful at everything in life because of it! \n\nTry out our different kinds of episodes to see what you like. And add it into your morning routine every day. Each day, you will be happier than the day before :)\n\nLeave a comment if you liked this episode! And don't forget to subscribe, so you never miss a new episode.\n\nYou can listen to Wake Me Up in audio-only format on your favorite podcast player! Visit www.wakemeuppodcast.com to learn more.\n\nWant more Wake Me Up? Join Wake Me Up Premium to get instant access to the entire WMU catalog of 400 episodes, including exclusive bonus episodes only available to premium supporters. Learn more and sign up here: https://wakemeup.supercast.com/\n\nFollow our network on Instagram and TikTok @_heychamp \n\nWarning about stretches, breathing, and other techniques: Only partake in the physical movements and practices suggested in Wake Me Up episodes if you are physically able and in safe surroundings. All movements are done at the individual's own risk. Be safe, and always consult a doctor if you have any questions or concerns.\n\n00:00 Introduction\n01:00 Meditation begins\n02:45 Affirmations begin\n09:13 Conclusion",
#     "url": "https://i.ytimg.com/vi/TN-xKFd2wIE/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Wake Me Up",
#     "liveBroadcastContent": "none",
#     "publishTime": "2024-02-21T07:00:21Z",
#     "id": "TN-xKFd2wIE",
#     "duration": "PT10M",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "22918",
#     "likeCount": "1538",
#     "favoriteCount": "0",
#     "commentCount": "181",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'B5F81GP36SAVSAUEM6M8LKTBI3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'B5F81GP36SAVSAUEM6M8LKTBI3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "WIAOIY6JRFHQIypkL2bCa2cZt5s",
#     "videoId": "nRYl9vXfvdo",
#     "publishedAt": "2023-01-29T15:00:34Z",
#     "channelId": "UC6ashd-m9GHYP6wozPCoC8A",
#     "title": "Positive Morning Affirmations - Success, Confidence, Abundance",
#     "description": "Transform your morning into a MIRACLE MORNING every day! Listen to these positive morning affirmations as you begin your ...",
#     "url": "https://i.ytimg.com/vi/nRYl9vXfvdo/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Jessica Heslop - Manifest by Jess",
#     "liveBroadcastContent": "none",
#     "publishTime": "2023-01-29T15:00:34Z",
#     "id": "nRYl9vXfvdo",
#     "duration": "PT9M3S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "792361",
#     "likeCount": "12290",
#     "favoriteCount": "0",
#     "commentCount": "461",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'M088LBOVC6VIBTU6DI398IRA1FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'M088LBOVC6VIBTU6DI398IRA1FVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "soJNUYjOuBz-eFqBTb3Svo03biA",
#     "videoId": "_tWzCP0s22U",
#     "publishedAt": "2021-05-10T10:30:03Z",
#     "channelId": "UC0dJDW1i1vgwGXJ19wjIHPg",
#     "title": "10 Most Powerful Affirmations of All Time | New Updated Version | Bob Baker",
#     "description": "Enjoy this new updated version of the 10 Most Powerful Affirmations of All Time. I published the original version of this popular video about nine months ago, and in a short time, it hit one million views. It\u2019s now close to 2 million, which proves that these 10 affirmations resonate with a lot of people. Includes powerful affirmations, best affirmations, top 10 affirmations, most powerful affirmations, bob baker affirmations, listen for 21 days.\n\n10 Most Powerful Affirmations of All Time - check out the new 2023 music version at https://youtu.be/MiRZyP7Dkio\nAnd the original 2020 version at https://youtu.be/5fQv1kHCAC4\n\nJoin the new High-Vibe Tribe Community at https://bobbakerinspiration.com/tribe\n\nReady to take your life to the next level? Submit your application to our VIP Mentorship Program at https://www.bobbakerinspiration.com/vip\n\nPURCHASE Bob's book, \"The Power of Affirmations and Positive Self-Talk.\" Info at https://bobbakerinspiration.com/book\n\nGet your FREE copy of \"How to Turbo-Charge Your Life!\" at https://bob-baker.aweb.page/turbo-charge-your-life - 5 Steps to Unleashing Purpose, Passion, and Play\n\nSUBSCRIBE to the channel so you don\u2019t miss all the new videos I publish every week\nhttps://www.youtube.com/channel/UC0dJDW1i1vgwGXJ19wjIHPg?sub_confirmation=1\n\nSAMPLE the \u201c21-Day Abundance and Money Attraction Brain Boost\u201d for free at https://bobbaker.samcart.com/products/21-day-abundance-boost\n\nFOLLOW Bob Baker\u2019s Inspiration Project on Spotify https://open.spotify.com/artist/2h5dkU6stcyzAXjMcgb1fe\n\nSAMPLE my most popular album here https://bobbakerinspiration.hearnow.com\n\nThanks to https://BetterHelp.com/BobBaker\u200b for sponsoring this video. Yes, you can take important steps to improve your mindset, but if you\u2019re really having a tough time, don\u2019t try to power through it alone. Get the help you need from a licensed therapist. If you use the BetterHelp service, I will receive a commission. That won\u2019t affect your rate at all, but it will help support my channel so I can create more videos like this one.\n\n0:00 Affirmations Intro\n0:55 10 Most Powerful Affirmations of All Time\n9:46 Final thoughts\n\n===\n\nAlso enjoy these YouTube playlists ...\n\nStart Your Day Morning Affirmations https://www.youtube.com/playlist?list=PLCNbem8fOiHr_JOONo7VUlJWbxMiJv23K\n\nAbundance, Prosperity, and Wealth Attraction https://www.youtube.com/playlist?list=PLCNbem8fOiHpDs4L9YQTKFfS8E_UfCZpZ\n\nConfidence, Self-Esteem, and Self-Worth https://www.youtube.com/playlist?list=PLCNbem8fOiHpDj_trJTSkZo07DJwiaesS\n\nGratitude Affirmations for Morning and Night https://www.youtube.com/playlist?list=PLCNbem8fOiHqE1jsDOHSM0JfWDZJcmEOd\n\nBedtime Sleep Affirmations for Prosperity, Success & Abundance https://www.youtube.com/playlist?list=PLCNbem8fOiHq1Mn796oKmiu63oo8mRG9q\n\nMorning Affirmations for Wealth, Abundance and Confidence https://www.youtube.com/playlist?list=PLCNbem8fOiHomHEiGaCIwgQGc6MnKfvx0\n\nGuided Meditations for Wealth, Abundance and Creativity https://www.youtube.com/playlist?list=PLCNbem8fOiHpxMsebKoEm7qHO14T4KJVE\n\nAffirmations for Creativity, Success and Abundance https://www.youtube.com/playlist?list=PLCNbem8fOiHrIgeCbuuWQVZD0SL91bHjb\n\n21 Day Meditation Challenge Videos https://www.youtube.com/playlist?list=PLCNbem8fOiHq8UnWVH66CYWQDW5mDkUG8\n\n===\n\n#Affirmations #BestAffirmations #21days #BobBaker  #Positivity #lawofattraction #MorningAffirmations\n\naffirmations of all time, 21 days, morning affirmations, affirmations, law of attraction, success, money, prosperity, wealth, positive affirmations, money affirmations, powerful money affirmations, affirmations for success, abundance, increasing motivation, creating miracles, subconscious mind, the secret, positive statements, wealth and abundance, rewire your brain, the 7 most powerful affirmations for wealth\n\n===\n\nAlso, I've published many books over the years, including:\nThe Passio ...
#     "url": "https://i.ytimg.com/vi/_tWzCP0s22U/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Bob Baker Affirmations",
#     "liveBroadcastContent": "none",
#     "publishTime": "2021-05-10T10:30:03Z",
#     "id": "_tWzCP0s22U",
#     "duration": "PT11M4S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "1313680",
#     "likeCount": "15347",
#     "favoriteCount": "0",
#     "commentCount": "471",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health",
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': '01DMNBTELODDBAB7G33VIJCEINVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '01DMNBTELODDBAB7G33VIJCEINVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "IST-wovmeMAkORD37JbEHmyWHFI",
#     "videoId": "5CtiouwHOxw",
#     "publishedAt": "2024-01-03T12:00:09Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Positive Affirmations to Manifest Your Dream Life \ud83c\udf1f",
#     "description": "Powerful positive affirmations to manifest your dream life in 2024! Listen to these affirmations daily to reprogram your mind for ...",
#     "url": "https://i.ytimg.com/vi/5CtiouwHOxw/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2024-01-03T12:00:09Z",
#     "id": "5CtiouwHOxw",
#     "duration": "PT16M42S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "260202",
#     "likeCount": "8401",
#     "favoriteCount": "0",
#     "commentCount": "233",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'JESDI7AAHCC1R8UBPQ64TDQBO3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'JESDI7AAHCC1R8UBPQ64TDQBO3VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "B_6NazXaIcSryfZn14Zbc24S2cw",
#     "videoId": "Y-KRpEnD7OQ",
#     "publishedAt": "2021-08-01T14:36:57Z",
#     "channelId": "UCq7x2gQDsU45B26qlbOdnaQ",
#     "title": "Affirmation (Grade 3, Randall Standridge) - Concert Band",
#     "description": "Check Out My New Album! https://randallstandridge.hearnow.com/ This one is for all the outcasts, the geeks, the marginalized, the ...",
#     "url": "https://i.ytimg.com/vi/Y-KRpEnD7OQ/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Randall Standridge",
#     "liveBroadcastContent": "none",
#     "publishTime": "2021-08-01T14:36:57Z",
#     "id": "Y-KRpEnD7OQ",
#     "duration": "PT4M55S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "69542",
#     "likeCount": "838",
#     "favoriteCount": "0",
#     "commentCount": "99",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Christian_music",
#         "https://en.wikipedia.org/wiki/Classical_music",
#         "https://en.wikipedia.org/wiki/Music"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'JFKFMF7H1NMPCBL592OJR2GRPVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'JFKFMF7H1NMPCBL592OJR2GRPVVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "bGiRlF2DzeQCJN9WpjUpyBL70Bg",
#     "videoId": "UKLPr0whc9Q",
#     "publishedAt": "2022-09-03T13:00:26Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Money Affirmations | Attract Abundance, Prosperity, Wealth \u2728 (Listen Daily!)",
#     "description": "Enjoy these positive affirmations for money, wealth, abundance and prosperity. Listen to this daily to manifest more abundance ...",
#     "url": "https://i.ytimg.com/vi/UKLPr0whc9Q/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-09-03T13:00:26Z",
#     "id": "UKLPr0whc9Q",
#     "duration": "PT12M16S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "1275614",
#     "likeCount": "20600",
#     "favoriteCount": "0",
#     "commentCount": "479",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': '4I37ILC1N6U84L6OQQJOJCJELNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '4I37ILC1N6U84L6OQQJOJCJELNVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "lqQHRZZNpliwtWvG8cJKmlfX0L4",
#     "videoId": "RhuhLc69hF0",
#     "publishedAt": "2023-08-27T12:30:13Z",
#     "channelId": "UC-ga3onzHSJFAGsIebtVeBg",
#     "title": "Gratitude Affirmations \u2728 Daily Affirmations to Attract Positivity &amp; Abundance",
#     "description": "Powerful positive affirmations for gratitude and thankfulness. Listen to these affirmations daily for 21 days to reprogram your mind ...",
#     "url": "https://i.ytimg.com/vi/RhuhLc69hF0/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Lavendaire",
#     "liveBroadcastContent": "none",
#     "publishTime": "2023-08-27T12:30:13Z",
#     "id": "RhuhLc69hF0",
#     "duration": "PT13M46S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "674166",
#     "likeCount": "13643",
#     "favoriteCount": "0",
#     "commentCount": "339",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:33
#  {'ResponseMetadata': {'RequestId': 'NPAV2G6D644VS3CHAMAPI52HJJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:33 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'NPAV2G6D644VS3CHAMAPI52HJJVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "axAxTFHnDbI4B-i0d5doOsQny-Y",
#     "videoId": "Pq4ZejMPrT8",
#     "publishedAt": "2023-01-11T11:15:01Z",
#     "channelId": "UC0dJDW1i1vgwGXJ19wjIHPg",
#     "title": "Morning GRATITUDE Affirmations 20 Minutes | Start Your Day with a\u00a0Grateful Heart",
# ...
#     "url": "https://i.ytimg.com/vi/IvgwCLmN8zQ/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Amit Kumarr Live",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-10-30T12:34:50Z",
#     "id": "IvgwCLmN8zQ",
#     "duration": "PT7M22S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "312644",
#     "likeCount": "15171",
#     "favoriteCount": "0",
#     "commentCount": "798"
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:40
#  {'ResponseMetadata': {'RequestId': 'S6UQ2654JAFHJFSPVDT7E9CI4BVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:40 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'S6UQ2654JAFHJFSPVDT7E9CI4BVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "kRvuts11cWAXW-OEjRMOTU9BFjY",
#     "videoId": "G8DVe5hNpBE",
#     "publishedAt": "2013-09-24T01:06:45Z",
#     "channelId": "UCqFzWxSCi39LnW1JKFR3efg",
#     "title": "Daily Affirmation: Dysfuntional Family - Saturday Night Live",
#     "description": "Subscribe to SaturdayNightLive: http://j.mp/1bjU39d Daily Affirmations: http://j.mp/18YaOjv SEASON 17: http://j.mp/17DRBVc This ...",
#     "url": "https://i.ytimg.com/vi/G8DVe5hNpBE/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Saturday Night Live",
#     "liveBroadcastContent": "none",
#     "publishTime": "2013-09-24T01:06:45Z",
#     "id": "G8DVe5hNpBE",
#     "duration": "PT5M36S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "172567",
#     "likeCount": "2509",
#     "favoriteCount": "0",
#     "commentCount": "201",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Entertainment",
#         "https://en.wikipedia.org/wiki/Film",
#         "https://en.wikipedia.org/wiki/Television_program"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:40
#  {'ResponseMetadata': {'RequestId': 'AA3PIIQCH55MJQ875D621FH3IFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:40 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'AA3PIIQCH55MJQ875D621FH3IFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "9FpB73vyxSDtQKALxYOHWNZm1Q0",
#     "videoId": "T6KsSgc1PNM",
#     "publishedAt": "2017-11-18T14:01:54Z",
#     "channelId": "UC0dJDW1i1vgwGXJ19wjIHPg",
#     "title": "Morning I AM Affirmations to START YOUR DAY! 21 Day Challenge",
#     "description": "Start your day with these powerful, positive morning I AM affirmations, inspired by Abraham Hicks, Louise Hay, Deepak Chopra, and Wayne Dyer. Take this 21 day meditation challenge and start the day by listening to these I AM affirmations daily for three weeks in a row. Wake up to positivity and kick start your day.\n\nDOWNLOAD 6 of my favorite affirmation and guided meditation recordings FREE. My gift to you. Get them here: https://BobBakerInspiration.com/free\n\n0:00 Introduction to Start Your Day Affirmations\n0:26 Morning I AM Affirmations Affirmations begin\n5:49 Alphabetical affirmations start\n\nSAMPLE the \u201c21-Day Abundance and Money Attraction Brain Boost\u201d for free at\nhttps://soulmassage.bandcamp.com/album/21-day-abundance-and-money-attraction-brain-boost\n\nSUPPORT Bob\u2019s mission to spread inspiration throughout the world with a one-time or ongoing donation!\nhttps://www.paypal.com/cgi-bin/webscr?cmd=_s-xclick&hosted_button_id=KHWVBQK3A4X3J&source=url \n\nFOLLOW Bob Baker\u2019s Inspiration Project on Spotify\nhttps://open.spotify.com/artist/2h5dkU6stcyzAXjMcgb1fe\n\nSTREAM & PURCHASE tracks on Apple Music\nhttps://itunes.apple.com/us/artist/bob-bakers-inspiration-project/1388646816\n\nThanks to https://BetterHelp.com/BobBaker for sponsoring this episode. Yes, you can take important steps to improve your mindset, but if you\u2019re really having a tough time, don\u2019t try to power through it alone. Get the help you need from a licensed therapist. If you use the BetterHelp service, I will receive a commission. That won\u2019t affect your rate at all, but it will help support my channel so I can create more videos like this one.\n\n=====\n\nAlso enjoy these YouTube playlists ...\n\nMorning Affirmations for Wealth, Abundance and Confidence\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHomHEiGaCIwgQGc6MnKfvx0\n\nGuided Meditations for Wealth, Abundance and Creativity\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHpxMsebKoEm7qHO14T4KJVE\n\nAffirmations for Creativity, Success and Abundance\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHrIgeCbuuWQVZD0SL91bHjb\n\n21 Day Meditation Challenge Videos\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHq8UnWVH66CYWQDW5mDkUG8\n\nGuided Meditations for Relaxation and Stress Relief\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHoGG9IFP-bbhIP_LyT3-5eX\n\nBedtime Sleep Affirmations for Prosperity, Success & Abundance\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHq1Mn796oKmiu63oo8mRG9q\n\nAffirmations for Health, Healing & Weight Loss\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHpwSp6bGTqbo2qVc3uSfOh7\n\nGratitude Affirmations for Morning and Bedtime\nhttps://www.youtube.com/playlist?list=PLCNbem8fOiHqE1jsDOHSM0JfWDZJcmEOd\n\nFollow my Bob Baker Inspiration page on Facebook:\nhttps://www.facebook.com/BobBakerInspiration/\n\n=====\n\nBackground music used in this video:\n\u201cThat Hopeful Future Is All I've Ever Known\u201d from the album \u201cMusic from Neptune Flux\u201d by Chris Zabriskie http://chriszabriskie.com/neptuneflux/\nLicensed under a Creative Commons Attribution license https://creativecommons.org/licenses/by/4.0/\n\n=====\n\n#Affirmations #MorningAffirmations #IAMAffirmations #IAM #GuidedMeditation #MorningMeditation #StartTheDay #StartYourDay #Morning #positivity\n\nMorning Affirmations To Start Your Day On The Right Foot (Daily Affirmations)\npositive affirmations to start your day\n21 day meditation challenge\nmorning i am affirmations\nHonest guys\nmorning Abraham Hicks\npositive morning motivation\nmorning Wayne dyer\npositive morning meditation\nmorning affirmations Louise Hay\nmorning Deepak Chopra\n42 morning affirmations\nmorning Jason Stephenson\n\nAlso, I've published many books over the years, including \u2026\n\nPersonal and Spiritual Growth for Fun People: The Secret Guide to Joy and Prosperity\nEbook https://amzn.to/2vkVFzx\nAudiobook https://amzn.to/2vaGad2\n\nThe Empowered Artist: A Call to  ...
#     "url": "https://i.ytimg.com/vi/T6KsSgc1PNM/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Bob Baker Affirmations",
#     "liveBroadcastContent": "none",
#     "publishTime": "2017-11-18T14:01:54Z",
#     "id": "T6KsSgc1PNM",
#     "duration": "PT10M1S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "true",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "2552901",
#     "likeCount": "41326",
#     "favoriteCount": "0",
#     "commentCount": "1000",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)",
#         "https://en.wikipedia.org/wiki/Religion"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:40
#  {'ResponseMetadata': {'RequestId': 'E8342LQLL8H7G1139F2T5GF3NFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:40 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'E8342LQLL8H7G1139F2T5GF3NFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "_JhEihZRFMPg_7cF_YDj6oNPnTc",
#     "videoId": "VaK5rBDnNSY",
#     "publishedAt": "2022-04-24T23:59:41Z",
#     "channelId": "UC2H3IyKJZNrlDbJjUJKQQBg",
#     "title": "WeeMove: Positive Affirmation Yoga for Kids",
#     "description": "A Morning Movement Practice for Clarity and Calm. Start the day with positive affirmations, mindful music, and yoga moves for ...",
#     "url": "https://i.ytimg.com/vi/VaK5rBDnNSY/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "WeeWoo | Heart Happy Kids",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-04-24T23:59:41Z",
#     "id": "VaK5rBDnNSY",
#     "duration": "PT7M5S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": false,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": true,
#     "viewCount": "6029",
#     "likeCount": "105",
#     "favoriteCount": "0",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)",
#         "https://en.wikipedia.org/wiki/Physical_fitness"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:41
#  {'ResponseMetadata': {'RequestId': 'UTNUFOLGQT1JFO6ENIVBCNQGL7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:41 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': 'UTNUFOLGQT1JFO6ENIVBCNQGL7VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "UO3iCDVMgoLI772PDIH-xnydKf0",
#     "videoId": "_GQWHw0OcaA",
#     "publishedAt": "2022-10-14T16:04:18Z",
#     "channelId": "UC64KwGynvj3hA7T0C9gC5cA",
#     "title": "Thewizardliz guided money meditation",
#     "description": "",
#     "url": "https://i.ytimg.com/vi/_GQWHw0OcaA/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Thewizardliz",
#     "liveBroadcastContent": "none",
#     "publishTime": "2022-10-14T16:04:18Z",
#     "id": "_GQWHw0OcaA",
#     "duration": "PT11M12S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "2441348",
#     "likeCount": "100206",
#     "favoriteCount": "0",
#     "commentCount": "3407",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Lifestyle_(sociology)"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:41
#  {'ResponseMetadata': {'RequestId': '2EB4I664RN7CPEGOLQRUPSK9NFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:41 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '2EB4I664RN7CPEGOLQRUPSK9NFVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}
# {
#     "kind": "youtube#video",
#     "etag": "mmf7Z5Gyarq-z5_ru8QpyvP0HuI",
#     "videoId": "IcbJy-VXwoM",
#     "publishedAt": "2020-08-24T18:15:06Z",
#     "channelId": "UCZzuauSCw9aXx-tUB-E7Tfw",
#     "title": "\u201cI AM\u201d Affirmations For Success,Wealth &amp; Happiness | This Will Go Straight to Your Subconscious Mind",
#     "description": "This affirmations meditation video is so powerful to help you attract and manifest HUGE amounts of wealth, success and ...",
#     "url": "https://i.ytimg.com/vi/IcbJy-VXwoM/hqdefault.jpg",
#     "width": 480,
#     "height": 360,
#     "channelTitle": "Master Sri Akarshana",
#     "liveBroadcastContent": "none",
#     "publishTime": "2020-08-24T18:15:06Z",
#     "id": "IcbJy-VXwoM",
#     "duration": "PT15M15S",
#     "dimension": "2d",
#     "definition": "hd",
#     "caption": "false",
#     "licensedContent": true,
#     "projection": "rectangular",
#     "uploadStatus": "processed",
#     "privacyStatus": "public",
#     "license": "youtube",
#     "embeddable": true,
#     "publicStatsViewable": true,
#     "madeForKids": false,
#     "viewCount": "701797",
#     "likeCount": "11621",
#     "favoriteCount": "0",
#     "commentCount": "447",
#     "topicCategories": [
#         "https://en.wikipedia.org/wiki/Health"
#     ]
# }
# Successfully inserted api results into DynamoDB  at 2024-02-29 00:20:41
#  {'ResponseMetadata': {'RequestId': '57FPENTE5C7JJVD1RRAV210SLRVV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Thu, 29 Feb 2024 08:20:41 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '2', 'connection': 'keep-alive', 'x-amzn-requestid': '57FPENTE5C7JJVD1RRAV210SLRVV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '2745614147'}, 'RetryAttempts': 0}}

# %%
import boto3
from dotenv import load_dotenv
from datetime import datetime
import os
import pandas as pd


def current_timestamp():
    """Returns the current timestamp formatted for readability."""
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
def open_aws_dynamodb_session(options):
    """
    Configures a boto3 session using AWS credentials read from environment variable.
    Returns a boto3 DynamoDB resource configured with these credentials.
    """
    try:

        # Configure the boto3 session with the read credentials
        session = boto3.Session(
            aws_access_key_id=options['AWS_ACCESS_KEY_ID'],
            aws_secret_access_key=options['AWS_SECRET_ACCESS_KEY'],
            region_name=options['AWS_REGION']  # Specify your AWS region
        )
        dynamodb_resource = session.resource('dynamodb')
        print(f"Successfully open_aws_dynamodb_session with environment variables. at {current_timestamp()}\n")
        # Return the configured DynamoDB resource
        return dynamodb_resource

    except Exception as e:
        print(f"Error open_aws_dynamodb_session from environment variables: {e} at {current_timestamp()}\n")
        return None

def get_env_variables():
    """Fetch all necessary configurations from environment variables."""
    return {
        'DEVELOPER_KEY': os.getenv('DEVELOPER_KEY'),
        'AWS_ACCESS_KEY_ID': os.getenv('AWS_ACCESS_KEY_ID'),
        'AWS_SECRET_ACCESS_KEY': os.getenv('AWS_SECRET_ACCESS_KEY'),
        'SEARCH_CACHE_TABLE': os.getenv('SEARCH_CACHE_TABLE'),
        'RESULTS_TABLE_NAME': os.getenv('RESULTS_TABLE_NAME'),
        'SEARCH_QUERY': os.getenv('SEARCH_QUERY'),
        'MAX_RESULTS': int(os.getenv('MAX_RESULTS', 50)),
        'ORDER': os.getenv('ORDER', 'viewCount'),
        'VIDEO_DURATION': os.getenv('VIDEO_DURATION', 'medium'),
        'PUBLISHED_AFTER': os.getenv('PUBLISHED_AFTER', '2010-01-01T00:00:00Z'),
        'PUBLISHED_BEFORE': os.getenv('PUBLISHED_BEFORE', '2024-12-31T23:59:59Z'),
        'RELEVANCE_LANGUAGE': os.getenv('RELEVANCE_LANGUAGE', 'en'),
        # 'VIDEO_CATEGORY_ID': os.getenv('VIDEO_CATEGORY_ID', '10'),
        'AWS_REGION': os.getenv('AWS_REGION')  # Add AWS region to the environment variables
    }

def query_and_sort_videos(table_name, search_keywords, dynamodb):
    """
    Queries a DynamoDB table for videos that match any of the provided keywords in their title or description,
    sorts the results by commentCount in descending order, and returns detailed information for the top 3 videos.

    :param table_name: The name of the DynamoDB table to search.
    :param search_keywords: A list of keywords to search for in video titles and descriptions.
    :param dynamodb: The DynamoDB session object.
    :return: A list of dictionaries containing detailed information for the top 3 videos sorted by commentCount in descending order.
    """
    table = dynamodb.Table(table_name)

    # Build filter expression dynamically based on the number of search keywords
    filter_expression = " or ".join([f"contains(title, :kw{i}) or contains(description, :kw{i})" for i, _ in enumerate(search_keywords, start=1)])
    expression_attribute_values = {f":kw{i}": kw for i, kw in enumerate(search_keywords, start=1)}

    response = table.scan(
        FilterExpression=filter_expression,
        ExpressionAttributeValues=expression_attribute_values
    )

    items = response.get('Items', [])
    # Ensure 'commentCount' is treated as an integer for sorting purposes
    for item in items:
        item['commentCount'] = int(item.get('commentCount', 0))

    # Sort items by 'commentCount' in descending order and select the top 3
    sorted_items = sorted(items, key=lambda x: x['commentCount'], reverse=True)[:3]

    return sorted_items


def query_all_videos(table_name, dynamodb):
    """
    Queries a DynamoDB table for videos without any specific keyword filter,
    sorts the results by commentCount in descending order, and returns detailed information for the top 3 videos.

    :param table_name: The name of the DynamoDB table to search.
    :param dynamodb: The DynamoDB session object.
    :return: A list of dictionaries containing detailed information for the top 3 videos sorted by commentCount in descending order.
    """
    table = dynamodb.Table(table_name)

    items = []
    scan_kwargs = {}
    done = False
    start_key = None

    while not done:
        if start_key:
            scan_kwargs['ExclusiveStartKey'] = start_key
        response = table.scan(**scan_kwargs)
        items.extend(response.get('Items', []))

        start_key = response.get('LastEvaluatedKey', None)
        done = start_key is None

    return items


def convert_to_dataframe(sorted_items):
    """
    Converts a list of sorted items into a pandas DataFrame.

    :param sorted_items: A list of sorted items by commentCount in descending order.
    :return: A pandas DataFrame of the sorted items.
    """
    if sorted_items:
        df = pd.DataFrame(sorted_items, columns=[
        "kind", "etag", "videoId", "publishedAt", "channelId", "title", "description",
        "url", "width", "height", "channelTitle", "liveBroadcastContent", "publishTime",
        "id", "duration", "dimension", "definition", "caption", "licensedContent",
        "projection", "uploadStatus", "privacyStatus", "license", "embeddable",
        "publicStatsViewable", "madeForKids", "viewCount", "likeCount", "favoriteCount",
        "commentCount", "topicCategories"
    ])
    else:
        print("No items found matching the criteria.")
        df = pd.DataFrame()

    return df


def clean_transcript(input_string):
    # Regex pattern to extract transcript text and replace brackets, "\n", "-->", and datetime
    cleaned_text = re.sub(r'<[^>]*>', ', ', input_string)  # Remove tags
    cleaned_text = re.sub(r' align:start position:\d+%', '', input_string)
    cleaned_text = re.sub(r'\d{2}:\d{2}:\d{2}\.\d{3} --> \d{2}:\d{2}:\d{2}\.\d{3}', '', cleaned_text)  # Remove datetime
    cleaned_text = re.sub(r'\n|-->', ' ', cleaned_text)  # Remove "\n" and "-->"
    cleaned_text = re.sub(r'<.*?>', '', cleaned_text)  # Remove remaining tags
    cleaned_text = re.sub(r'\[|\]', ', ', cleaned_text)  # Replace brackets with ", "
    cleaned_text = re.sub(r'   ', ' ', cleaned_text)  # remove excess spaces
    cleaned_text = re.sub(r'  ', ' ', cleaned_text)  # remove excess spaces
    
    return cleaned_text

# Example usage
if __name__ == "__main__":
    load_dotenv()
    options = get_env_variables()
    if options:
        table_name = options['RESULTS_TABLE_NAME']
        dynamodb = open_aws_dynamodb_session(options)
        if dynamodb:
            search_keywords = ["Self Love", "Confidence"]
        
            # video_attributes_list = query_and_sort_videos(table_name, search_keywords, dynamodb)
            # df = convert_to_dataframe(video_attributes_list)
            all_videos_in_dynamodb = query_all_videos(table_name, dynamodb)
            df = convert_to_dataframe(all_videos_in_dynamodb)
            # df.to_csv('all_latest_records_dynamodb.csv', index=False)
            print(df.shape)
            # print(video_ids)
            # for video_id in video_ids_list:
            #     # Input string containing transcript
            #     subtitle_file, transcript_text = download_subtitles('OU5vWLaIpnY')
                
            #     # Call the function to clean the transcript text
            #     cleaned_transcript = clean_transcript(transcript_text)
            #     print(cleaned_transcript)
# Out:
# Successfully open_aws_dynamodb_session with environment variables. at 2024-03-01 17:15:15
#
# (608, 31)

# %%
pd.set_option('display.max_columns', None)

df.to_csv('all_latest_records_dynamodb.csv', index=False)
df.sample(2)
# Out:
#               kind                         etag      videoId  \
# 544  youtube#video  Oym55xB1vydEtmoSu3VA60NkfKo  Rgc7L30FmlM
# 590  youtube#video  XZbyfDzKz8t0A7VJoZ_6NHjUs8Y  O3nVWBNURFk
#
#               publishedAt                 channelId  \
# 544  2022-01-02T00:35:32Z  UCjdvLPmF0iUeoX7uLFtWmwg
# 590  2024-02-28T13:04:09Z  UCJnTW8HXgTMkwfAEu_LBFYQ
#
#                                                  title  \
# 544  Affirmation by Randall Standridge - Walsh Midd...
# 590  Affirmation prayer, You are about to receive a...
#
#                                            description  \
# 544  Performed by the Walsh Middle School Honor Ban...
# 590  Affirmation prayer, You are about to receive a...
#
#                                                   url width height  \
# 544  https://i.ytimg.com/vi/Rgc7L30FmlM/hqdefault.jpg   480    360
# 590  https://i.ytimg.com/vi/O3nVWBNURFk/hqdefault.jpg   480    360
#
#            channelTitle liveBroadcastContent           publishTime  \
# 544          Walsh Band                 none  2022-01-02T00:35:32Z
# 590  Prophetic Prayers_                 none  2024-02-28T13:04:09Z
#
#               id duration dimension definition caption  licensedContent  \
# 544  Rgc7L30FmlM  PT4M57S        2d         hd   false            False
# 590  O3nVWBNURFk  PT4M29S        2d         hd   false            False
#
#       projection uploadStatus privacyStatus  license  embeddable  \
# 544  rectangular    processed        public  youtube        True
# 590  rectangular    processed        public  youtube        True
#
#      publicStatsViewable  madeForKids viewCount likeCount favoriteCount  \
# 544                 True         True      3419       NaN             0
# 590                 True        False      1281       117             0
#
#     commentCount                                    topicCategories
# 544            0  [https://en.wikipedia.org/wiki/Classical_music...
# 590          145  [https://en.wikipedia.org/wiki/Christian_music...

# %%
import re

def download_subtitles(video_id):
    """Download subtitles for a given YouTube video ID."""
    video_url = f'https://www.youtube.com/watch?v={video_id}'
    ydl_opts = {
        'writeautomaticsub': True,
        'subtitleslangs': ['en'],
        'skip_download': True,
        'outtmpl': f'subtitles/{video_id}.%(ext)s',
        'quiet': True
    }
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([video_url])
            subtitle_file = f'subtitles/{video_id}.en.vtt'
            if os.path.exists(subtitle_file):
                with open(subtitle_file, 'r', encoding='utf-8') as file:
                    subtitle_text = file.read()
                    print(f"Downloaded video subtitles for video ID: {video_id} into the file {subtitle_file} at {current_timestamp()}\n")
                return subtitle_file, subtitle_text
            return None, None
    except Exception as e:
        print(f"Failed to download subtitles for video ID: {video_id}: {e} at {current_timestamp()}\n")
        return None, None


def clean_transcript(input_string):
    # Regex pattern to extract transcript text and replace brackets, "\n", "-->", and datetime
    cleaned_text = re.sub(r'<[^>]*>', ', ', input_string)  # Remove tags
    cleaned_text = re.sub(r' align:start position:\d+%', '', input_string)
    cleaned_text = re.sub(r'\d{2}:\d{2}:\d{2}\.\d{3} --> \d{2}:\d{2}:\d{2}\.\d{3}', '', cleaned_text)  # Remove datetime
    cleaned_text = re.sub(r'\n|-->', ' ', cleaned_text)  # Remove "\n" and "-->"
    cleaned_text = re.sub(r'<.*?>', '', cleaned_text)  # Remove remaining tags
    cleaned_text = re.sub(r'\[|\]', ', ', cleaned_text)  # Replace brackets with ", "
    cleaned_text = re.sub(r'   ', ' ', cleaned_text)  # remove excess spaces
    cleaned_text = re.sub(r'  ', ' ', cleaned_text)  # remove excess spaces
    
    return cleaned_text



# Ensure the subtitles directory exists}
os.makedirs('subtitles', exist_ok=True)

# Input string containing transcript
subtitle_file, transcript_text = download_subtitles('OU5vWLaIpnY')

# Call the function to clean the transcript text
cleaned_transcript = clean_transcript(transcript_text)
print(cleaned_transcript)
# Out:
# Downloaded video subtitles for video ID: OU5vWLaIpnY into the file subtitles/OU5vWLaIpnY.en.vtt at 2024-02-29 01:01:41
#
# WEBVTT Kind: captions Language: en  welcome to the seven day money welcome to the seven day money  welcome to the seven day money manifestation challenge the purpose of manifestation challenge the purpose of  manifestation challenge the purpose of this recording is to help you generate this recording is to help you generate  this recording is to help you generate extra cash flow within the next week and extra cash flow within the next week and  extra cash flow within the next week and let me be clear I'm not talking about let me be clear I'm not talking about  let me be clear I'm not talking about just having an abundance mindset don't just having an abundance mindset don't  just having an abundance mindset don't get me wrong your mindset is vitally get me wrong your mindset is vitally  get me wrong your mindset is vitally important but my ultimate goal for you important but my ultimate goal for you  important but my ultimate goal for you is to have actual money in hand or in is to have actual money in hand or in  is to have actual money in hand or in the bank within one week so whether the bank within one week so whether  the bank within one week so whether you're listening to this on day 1 day 3 you're listening to this on day 1 day 3  you're listening to this on day 1 day 3 or day 7 welcome quickly there are two or day 7 welcome quickly there are two  or day 7 welcome quickly there are two things you should do to get the most out things you should do to get the most out  things you should do to get the most out of this 7 day challenge 1 is listen to of this 7 day challenge 1 is listen to  of this 7 day challenge 1 is listen to this recording every morning for seven this recording every morning for seven  this recording every morning for seven days in a row and be sure to repeat the days in a row and be sure to repeat the  days in a row and be sure to repeat the affirmations back to yourself I'll get affirmations back to yourself I'll get  affirmations back to yourself I'll get to those at a moment for an even bigger to those at a moment for an even bigger  to those at a moment for an even bigger impact write down or print the impact write down or print the  impact write down or print the affirmations and read them multiple affirmations and read them multiple  affirmations and read them multiple times throughout your day that's not a times throughout your day that's not a  times throughout your day that's not a big commitment it's only one week you big commitment it's only one week you  big commitment it's only one week you can do this also and this is really can do this also and this is really  can do this also and this is really important every day leave a comment important every day leave a comment  important every day leave a comment below this video with evidence of below this video with evidence of  below this video with evidence of abundance in your life from big things abundance in your life from big things  abundance in your life from big things like job promotions and new freelance like job promotions and new freelance  like job promotions and new freelance gigs to small things like finding $10.00 gigs to small things like finding $10.00  gigs to small things like finding $10.00 in an old pair of jeans or finding a in an old pair of jeans or finding a  in an old pair of jeans or finding a quarter on the ground it all reinforces quarter on the ground it all reinforces  quarter on the ground it all reinforces the fact that abundance and money are the fact that abundance and money are  the fact that abundance and money are flowing into your life ok let's jump flowing into your life ok let's jump  flowing into your life ok let's jump into these powerful money manifestation into these powerful money manifestation  into these powerful money manifestation affirmations I'll recite each one in the affirmations I'll recite each one in the  affirmations I'll recite each one in the space that follows you can repeat it space th ...

# %%
import os
import yt_dlp
from datetime import datetime

def current_timestamp():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def download_subtitles(video_id):
    """Download subtitles for a given YouTube video ID."""
    video_url = f'https://www.youtube.com/watch?v={video_id}'
    ydl_opts = {
        'writeautomaticsub': True,
        'subtitleslangs': ['en'],
        'skip_download': True,
        'outtmpl': f'subtitles/{video_id}.%(ext)s',
        'quiet': True
    }
    
    subtitle_file = f'subtitles/{video_id}.en.vtt'
    
    if os.path.exists(subtitle_file):
        with open(subtitle_file, 'r', encoding='utf-8') as file:
            subtitle_text = file.read()
            print(f"Subtitles for video ID: {video_id} already exist. Returning existing subtitles at {current_timestamp()}\n")
        return subtitle_file, subtitle_text
    
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([video_url])
            if os.path.exists(subtitle_file):
                with open(subtitle_file, 'r', encoding='utf-8') as file:
                    subtitle_text = file.read()
                    print(f"Downloaded video subtitles for video ID: {video_id} into the file {subtitle_file} at {current_timestamp()}\n")
                return subtitle_file, subtitle_text
            return None, None
    except Exception as e:
        print(f"Failed to download subtitles for video ID: {video_id}: {e} at {current_timestamp()}\n")
        return None, None

def clean_transcript(input_string):
    # Regex pattern to extract transcript text and replace brackets, "\n", "-->", and datetime
    cleaned_text = re.sub(r'<[^>]*>', ', ', input_string)  # Remove tags
    cleaned_text = re.sub(r' align:start position:\d+%', '', input_string)
    cleaned_text = re.sub(r'\d{2}:\d{2}:\d{2}\.\d{3} --> \d{2}:\d{2}:\d{2}\.\d{3}', '', cleaned_text)  # Remove datetime
    cleaned_text = re.sub(r'\n|-->', ' ', cleaned_text)  # Remove "\n" and "-->"
    cleaned_text = re.sub(r'<.*?>', '', cleaned_text)  # Remove remaining tags
    cleaned_text = re.sub(r'\[|\]', ', ', cleaned_text)  # Replace brackets with ", "
    cleaned_text = re.sub(r'   ', ' ', cleaned_text)  # remove excess spaces
    cleaned_text = re.sub(r'  ', ' ', cleaned_text)  # remove excess spaces
    
    return cleaned_text



# Ensure the subtitles directory exists}
os.makedirs('subtitles', exist_ok=True)

# Input string containing transcript
subtitle_file, transcript_text = download_subtitles('2bbHZusVgw0')

# Call the function to clean the transcript text
cleaned_transcript = clean_transcript(transcript_text)
print(cleaned_transcript)
# Out:
# Downloaded video subtitles for video ID: 2bbHZusVgw0 into the file subtitles/2bbHZusVgw0.en.vtt at 2024-02-29 01:09:34
#
# WEBVTT Kind: captions Language: en  morning morning  morning I am affirmations to attract wealth I am affirmations to attract wealth  I am affirmations to attract wealth abundance and prosperity listen to this abundance and prosperity listen to this  abundance and prosperity listen to this powerful recording once a day for 21 powerful recording once a day for 21  powerful recording once a day for 21 days in a row and you just might be days in a row and you just might be  days in a row and you just might be amazed by what shows up in your life amazed by what shows up in your life  amazed by what shows up in your life ready I'll recite each affirmation then ready I'll recite each affirmation then  ready I'll recite each affirmation then you'll repeat the statement back to you'll repeat the statement back to  you'll repeat the statement back to yourself either out loud or in your mind yourself either out loud or in your mind  yourself either out loud or in your mind and the more energy in emotion and and the more energy in emotion and  and the more energy in emotion and certainty that you put behind the certainty that you put behind the  certainty that you put behind the statements the more engrained they will statements the more engrained they will  statements the more engrained they will become let's begin I've vibrate with the become let's begin I've vibrate with the  become let's begin I've vibrate with the frequency of prosperity my life is the frequency of prosperity my life is the  frequency of prosperity my life is the embodiment of abundance   I've vibrate with the frequency of I've vibrate with the frequency of  I've vibrate with the frequency of success I see abundance everywhere I've success I see abundance everywhere I've  success I see abundance everywhere I've vibrate with the frequency of wealth I   am a money magnet money comes to me in am a money magnet money comes to me in  am a money magnet money comes to me in both expected and unexpected ways I both expected and unexpected ways I  both expected and unexpected ways I , Music,  welcome new streams of income welcome new streams of income  welcome new streams of income I welcome prosperity into my life I am I welcome prosperity into my life I am  I welcome prosperity into my life I am grateful for the many ways that money grateful for the many ways that money  grateful for the many ways that money comes to me wealth eagerly flows into my comes to me wealth eagerly flows into my  comes to me wealth eagerly flows into my life my inspired actions create ongoing life my inspired actions create ongoing  life my inspired actions create ongoing prosperity prosperity  prosperity , Music, , Music, , Music, I am aligned with the energy of I am aligned with the energy of  I am aligned with the energy of abundance I attract money making abundance I attract money making  abundance I attract money making opportunities I am a master of my wealth   the money I attract creates a positive the money I attract creates a positive  the money I attract creates a positive impact on the world money expands my impact on the world money expands my  impact on the world money expands my ability to serve others all of my needs ability to serve others all of my needs  ability to serve others all of my needs are met I am so grateful for the many are met I am so grateful for the many  are met I am so grateful for the many ways that money flows to me   I've vibrate with the frequency of I've vibrate with the frequency of  I've vibrate with the frequency of prosperity i vibrate with the frequency prosperity i vibrate with the frequency  prosperity i vibrate with the frequency of abundance i've vibrate with the of abundance i've vibrate with the  of abundance i've vibrate with the frequency of wealth i am worthy to frequency of wealth i am worthy to  frequency of wealth i am worthy to receive I bring immense value to the receive I bring immense value to the  receive I bring immense value to the wo ...

# %%
from collections import OrderedDict

def remove_duplicates(input_string):
    # Split the input string into phrases
    phrases = input_string.split()
    
    # Use an OrderedDict to maintain the order while eliminating duplicates
    unique_phrases = list(OrderedDict.fromkeys(phrases))
    
    # Join the unique phrases back into a string
    unique_string = ' '.join(unique_phrases)
    
    return unique_string


# Call the function to remove duplicate long phrases
unique_string = remove_duplicates(cleaned_transcript)
print(unique_string)
# Out:
# WEBVTT Kind: captions Language: en morning I am affirmations to attract wealth abundance and prosperity listen this powerful recording once a day for 21 days in row you just might be amazed by what shows up your life ready I'll recite each affirmation then you'll repeat the statement back yourself either out loud or mind more energy emotion certainty that put behind statements engrained they will become let's begin I've vibrate with frequency of my is embodiment success see everywhere money magnet comes me both expected unexpected ways , Music, welcome new streams income into grateful many eagerly flows inspired actions create ongoing aligned making opportunities master creates positive impact on world expands ability serve others all needs are met so i i've worthy receive bring immense value have gifts only uniquely qualified share perfect as deserve financially rewarded birthright way good responsible steward know core truly blessed blessing community people enjoy its forms better place because here vibe rate

# %%
import boto3

def count_rows_in_table(table_name, dynamodb=None):
    """
    Counts the number of rows in a specified DynamoDB table.

    :param table_name: The name of the DynamoDB table.
    :param dynamodb: The DynamoDB session object (optional).
    :return: The number of rows in the table.
    """
    if dynamodb is None:
        dynamodb = boto3.resource('dynamodb')

    table = dynamodb.Table(table_name)
    # Start the scan operation with minimal projection to reduce consumed capacity
    response = table.scan(ProjectionExpression='id')
    items = response.get('Items', [])

    # Continue scanning if more items are available
    while 'LastEvaluatedKey' in response:
        response = table.scan(
            ProjectionExpression='id',
            ExclusiveStartKey=response['LastEvaluatedKey']
        )
        items.extend(response.get('Items', []))

    # Return the count of items (rows) in the table
    return len(items)



# Example usage
if __name__ == "__main__":
    load_dotenv()
    options = get_env_variables()
    if options:
        table_name = options['RESULTS_TABLE_NAME']
        dynamodb = open_aws_dynamodb_session(options)
        if dynamodb:
            row_count = count_rows_in_table(table_name, dynamodb)
            print(f"Number of rows in table '{table_name}': {row_count}")
# Out:
# Successfully open_aws_dynamodb_session with environment variables. at 2024-03-01 21:34:32
#
# Number of rows in table 'YoutubeSearchResults': 618
